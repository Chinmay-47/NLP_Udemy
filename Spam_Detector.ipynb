# %% [markdown]
# <a href="https://colab.research.google.com/github/Chinmay-47/NLP_Udemy/blob/master/Spam_Detector.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Data
#url 'https://archive.ics.uci.edu/ml/datasets/spambase/spambase.data'

# %%
from sklearn.naive_bayes import MultinomialNB
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('spambase.data')
data
# Out:
#          0  0.64  0.64.1  0.1  0.32   0.2  ...   0.43   0.44  3.756   61   278  1
# 0     0.21  0.28    0.50  0.0  0.14  0.28  ...  0.180  0.048  5.114  101  1028  1
# 1     0.06  0.00    0.71  0.0  1.23  0.19  ...  0.184  0.010  9.821  485  2259  1
# 2     0.00  0.00    0.00  0.0  0.63  0.00  ...  0.000  0.000  3.537   40   191  1
# 3     0.00  0.00    0.00  0.0  0.63  0.00  ...  0.000  0.000  3.537   40   191  1
# 4     0.00  0.00    0.00  0.0  1.85  0.00  ...  0.000  0.000  3.000   15    54  1
# ...    ...   ...     ...  ...   ...   ...  ...    ...    ...    ...  ...   ... ..
# 4595  0.31  0.00    0.62  0.0  0.00  0.31  ...  0.000  0.000  1.142    3    88  0
# 4596  0.00  0.00    0.00  0.0  0.00  0.00  ...  0.000  0.000  1.555    4    14  0
# 4597  0.30  0.00    0.30  0.0  0.00  0.00  ...  0.000  0.000  1.404    6   118  0
# 4598  0.96  0.00    0.00  0.0  0.32  0.00  ...  0.000  0.000  1.147    5    78  0
# ...

# %%
data = np.asarray(data)
np.random.shuffle(data)

# %%
X = data[:, :57]
Y = data[:, -1]

# %%
Xtrain = X[:-100,]
Ytrain = Y[:-100,]
Xtest = X[-100:,]
Ytest = Y[-100:,]

# %%
model = MultinomialNB()

# %%
model.fit(Xtrain,Ytrain)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
print('classification rate for MB: ', model.score(Xtest,Ytest))
# Out:
# classification rate for MB:  0.8

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
model1 = AdaBoostClassifier()

# %%
model1.fit(Xtrain,Ytrain)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None, learning_rate=1.0,
#                    n_estimators=50, random_state=None)

# %%
print('classification rate for Adaboost: ', model1.score(Xtest,Ytest))
# Out:
# classification rate for Adaboost:  0.92
